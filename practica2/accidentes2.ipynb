# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import zscore
import sklearn.preprocessing as preproc
from sklearn.cluster import KMeans
from collections import Counter
from pract2_utils import *

# %%
RESULTS='results/accidentes/'
DATA='data/accidentes_2013.csv'

def readData(results_file):
    return pd.read_csv(results_file,header=0,engine='python')

# %%
dataTot=readData(DATA)
dataTot
# Out:
#        MES  HORA  DIASEMANA  PROVINCIA COMUNIDAD_AUTONOMA        ISLA  \
# 0        8  14.0          3    Bizkaia         País Vasco  NO_ES_ISLA
# 1        6  18.0          6    Bizkaia         País Vasco  NO_ES_ISLA
# 2       11  17.0          2  Tarragona           Cataluña  NO_ES_ISLA
# 3        1   9.0          3     Lleida           Cataluña  NO_ES_ISLA
# 4       11  22.0          7  Barcelona           Cataluña  NO_ES_ISLA
# ...    ...   ...        ...        ...                ...         ...
# 89514    6  19.0          5    Melilla    Ceuta y Melilla  NO_ES_ISLA
# 89515    4  17.0          4    Melilla    Ceuta y Melilla  NO_ES_ISLA
# 89516    1  23.0          5    Melilla    Ceuta y Melilla  NO_ES_ISLA
# 89517    2  15.0          3    Melilla    Ceuta y Melilla  NO_ES_ISLA
# 89518   10  11.0          6    Melilla    Ceuta y Melilla  NO_ES_ISLA
#
#        TOT_VICTIMAS  TOT_VICTIMAS30D  TOT_MUERTOS  TOT_MUERTOS30D  ...  \
# 0                 3                3            0        0.054104  ...
# 1                 1                1            0        0.000000  ...
# 2                 2                2            0        0.000000  ...
# 3                 2                2            0        0.000000  ...
# 4                 2                2            0        0.000000  ...
# ...             ...              ...          ...             ...  ...
# 89514             1                1            0        0.018035  ...
# 89515             1                1            0        0.000000  ...
# 89516             1                1            0        0.018035  ...
# 89517             2                2            0        0.000000  ...
# 89518             2                2            0        0.000000  ...
#
#                    PRIORIDAD  SUPERFICIE_CALZADA  \
# 0       NINGUNA (SOLO NORMA)              MOJADA
# 1                   SEMÁFORO              MOJADA
# 2              SEÑAL DE STOP       SECA Y LIMPIA
# 3                          ?              MOJADA
# 4                          ?              MOJADA
# ...                      ...                 ...
# 89514   NINGUNA (SOLO NORMA)       SECA Y LIMPIA
# 89515   NINGUNA (SOLO NORMA)       SECA Y LIMPIA
# 89516  SEÑAL DE CEDA EL PASO       SECA Y LIMPIA
# 89517   NINGUNA (SOLO NORMA)       SECA Y LIMPIA
# 89518   NINGUNA (SOLO NORMA)       SECA Y LIMPIA
#
#                          LUMINOSIDAD  FACTORES_ATMOSFERICOS  \
# 0                          PLENO DÍA          LLUVIA FUERTE
# 1                          PLENO DÍA            LLOVIZNANDO
# 2                          PLENO DÍA            BUEN TIEMPO
# 3                          PLENO DÍA            LLOVIZNANDO
# 4      NOCHE: ILUMINACIÓN SUFICIENTE          LLUVIA FUERTE
# ...                              ...                    ...
# 89514                      PLENO DÍA            BUEN TIEMPO
# 89515                      PLENO DÍA            BUEN TIEMPO
# 89516  NOCHE: ILUMINACIÓN SUFICIENTE            BUEN TIEMPO
# 89517                      PLENO DÍA            BUEN TIEMPO
# 89518                      PLENO DÍA            BUEN TIEMPO
#
#        VISIBILIDAD_RESTRINGIDA OTRA_CIRCUNSTANCIA        ACERAS  \
# 0        FACTORES ATMOSFÉRICOS               OTRA  NO HAY ACERA
# 1                   OTRA_CAUSA            NINGUNA  NO HAY ACERA
# 2                            ?            NINGUNA  NO HAY ACERA
# 3                            ?            NINGUNA  NO HAY ACERA
# 4                            ?            NINGUNA  NO HAY ACERA
# ...                        ...                ...           ...
# 89514          SIN RESTRICCIÓN            NINGUNA  SI HAY ACERA
# 89515          SIN RESTRICCIÓN            NINGUNA  SI HAY ACERA
# 89516          SIN RESTRICCIÓN            NINGUNA  SI HAY ACERA
# 89517          SIN RESTRICCIÓN            NINGUNA  SI HAY ACERA
# 89518               OTRA_CAUSA            NINGUNA  SI HAY ACERA
#
#                                           TIPO_ACCIDENTE DENSIDAD_CIRCULACION  \
# 0              Colisión de vehículos en marcha (Frontal)               FLUIDA
# 1              Colisión de vehículos en marcha (Alcance)                DENSA
# 2        Colisión de vehículos en marcha (Frontolateral)                    ?
# 3      Colisión de vehículos en marcha (Múltiple o en...                    ?
# 4        Colisión de vehículos en marcha (Frontolateral)                    ?
# ...                                                  ...                  ...
# 89514              Atropello a peatón aislado o en grupo               FLUIDA
# 89515          Colisión de vehículos en marcha (Lateral)               FLUIDA
# 89516    Colisión de vehículos en marcha (Frontolateral)               FLUIDA
# 89517          Colisión de vehículos en marcha (Alcance)                DENSA
# 89518          Colisión de vehículos en marcha (Lateral)               FLUIDA
#
#       MEDIDAS_ESPECIALES
# 0         NINGUNA MEDIDA
# 1         NINGUNA MEDIDA
# 2                      ?
# 3         NINGUNA MEDIDA
# 4                      ?
# ...                  ...
# 89514     NINGUNA MEDIDA
# 89515     NINGUNA MEDIDA
# 89516     NINGUNA MEDIDA
# 89517     NINGUNA MEDIDA
# 89518     NINGUNA MEDIDA
#
# [89519 rows x 32 columns]

# %%
dataTot.columns
# Out:
# Index(['MES', 'HORA', 'DIASEMANA', 'PROVINCIA', 'COMUNIDAD_AUTONOMA', 'ISLA',
#        'TOT_VICTIMAS', 'TOT_VICTIMAS30D', 'TOT_MUERTOS', 'TOT_MUERTOS30D',
#        'TOT_HERIDOS_GRAVES', 'TOT_HERIDOS_GRAVES30D', 'TOT_HERIDOS_LEVES',
#        'TOT_HERIDOS_LEVES30D', 'TOT_VEHICULOS_IMPLICADOS', 'ZONA',
#        'ZONA_AGRUPADA', 'RED_CARRETERA', 'TIPO_VIA', 'TRAZADO_NO_INTERSEC',
#        'TIPO_INTERSEC', 'ACOND_CALZADA', 'PRIORIDAD', 'SUPERFICIE_CALZADA',
#        'LUMINOSIDAD', 'FACTORES_ATMOSFERICOS', 'VISIBILIDAD_RESTRINGIDA',
#        'OTRA_CIRCUNSTANCIA', 'ACERAS', 'TIPO_ACCIDENTE',
#        'DENSIDAD_CIRCULACION', 'MEDIDAS_ESPECIALES'],
#       dtype='object')

# %%
# Atributos numéricos que reflejan la gravedad del accidente, sobre los que haré clustering
atributos=['TOT_VICTIMAS','TOT_MUERTOS','TOT_HERIDOS_GRAVES','TOT_HERIDOS_LEVES','TOT_VEHICULOS_IMPLICADOS']

# %% [markdown]
# ## Caso de uso 2: Estudio de los accidentes a altas horas de la madrugada

# %% [markdown]
# Filtramos los datos para quedarnos con accidentes que ocurren a altas horas de la madrugada.

# %%
data=dataTot[dataTot.HORA<=6]
data=data[atributos]
data
# Out:
#        TOT_VICTIMAS  TOT_MUERTOS  TOT_HERIDOS_GRAVES  TOT_HERIDOS_LEVES  \
# 21                2            0                   0                  2
# 45                3            0                   1                  2
# 46                2            0                   0                  2
# 57                1            1                   0                  0
# 86                1            0                   0                  1
# ...             ...          ...                 ...                ...
# 89423             3            0                   0                  3
# 89435             3            0                   0                  3
# 89446             2            0                   0                  2
# 89447             3            0                   0                  3
# 89466             1            0                   0                  1
#
#        TOT_VEHICULOS_IMPLICADOS
# 21                            1
# 45                            1
# 46                            1
# 57                            2
# 86                            1
# ...                         ...
# 89423                         1
# 89435                         2
# 89446                         2
# 89447                         2
# 89466                         2
#
# [5969 rows x 5 columns]

# %%
# Algunas variables tienen valores extremos, que distorsionan las gráficas
for a in atributos:
    print(a)
    print(Counter(data[a]))
# Out:
# TOT_VICTIMAS
# Counter({1: 3404, 2: 844, 3: 292, 4: 117, 5: 60, 6: 17, 7: 16, 8: 4, 9: 2, 10: 2, 18: 1, 52: 1})
# TOT_MUERTOS
# Counter({0: 4665, 1: 83, 2: 11, 4: 1})
# TOT_HERIDOS_GRAVES
# Counter({0: 4023, 1: 666, 2: 59, 3: 4, 5: 4, 4: 4})
# TOT_HERIDOS_LEVES
# Counter({1: 2962, 2: 728, 0: 619, 3: 266, 4: 106, 5: 44, 6: 16, 7: 11, 8: 3, 9: 2, 17: 1, 47: 1, 10: 1})
# TOT_VEHICULOS_IMPLICADOS
# Counter({2: 2475, 1: 2070, 3: 177, 4: 28, 5: 7, 9: 1, 6: 1, 7: 1})

# %%
# Box Plot
n_var = len(atributos)
fig, axes = plt.subplots(1, n_var, sharey=True, figsize=(15,5))
fig.subplots_adjust(wspace=0, hspace=0)

colors = sns.color_palette(palette=None, n_colors=n_var, desat=None)

rango = []
for j in range(n_var):
    d=data[atributos[j]]
    rango.append([d.min(), d.max()])

for i in range(1):
    dat_filt = data
    for j in range(n_var):
        ax  = sns.boxplot(x=dat_filt[atributos[j]],
                         color=colors[i],
                         flierprops={
                             'marker': 'o',
                             'markersize': 4
                         },
                         ax=axes[j], whis=3,showfliers=True)

        if (i == 0):
            axes[j].set_xlabel(atributos[j])
        else:
            axes[j].set_xlabel("")

        if (j == 0):
            axes[j].set_ylabel("Cluster " + str(i + 1))
        else:
            axes[j].set_ylabel("")

        axes[j].set_yticks([])
        axes[j].grid(axis='x',
                        linestyle='-',
                        linewidth='0.2',
                        color='gray')
        axes[j].grid(axis='y', b=False)

        ax.set_xlim(rango[j][0] - 0.05 * (rango[j][1] - rango[j][0]),
                    rango[j][1] + 0.05 * (rango[j][1] - rango[j][0]))

# %%
# Eliminar outliers, ya que distorsionan las gráficas
for a in atributos:
    if a in {'TOT_MUERTOS','TOT_HERIDOS_GRAVES'}:
        continue
    d=data[a][abs(zscore(data[a]))<3]
    data[a][zscore(data[a])<-3]=d.min()
    data[a][zscore(data[a])>3]=d.max()

# %%
# Algunas variables tienen valores extremos, que distorsionan las gráficas
for a in atributos:
    print(a)
    print(Counter(data[a]))
# Out:
# TOT_VICTIMAS
# Counter({1: 3404, 2: 844, 3: 292, 4: 117, 5: 103})
# TOT_MUERTOS
# Counter({0: 4665, 1: 83, 2: 11, 4: 1})
# TOT_HERIDOS_GRAVES
# Counter({0: 4023, 1: 666, 2: 59, 3: 4, 5: 4, 4: 4})
# TOT_HERIDOS_LEVES
# Counter({1: 2962, 2: 728, 0: 619, 3: 266, 4: 185})
# TOT_VEHICULOS_IMPLICADOS
# Counter({2: 2475, 1: 2070, 3: 215})

# %%
# Box Plot
n_var = len(atributos)
fig, axes = plt.subplots(1, n_var, sharey=True, figsize=(15,5))
fig.subplots_adjust(wspace=0, hspace=0)

colors = sns.color_palette(palette=None, n_colors=n_var, desat=None)

rango = []
for j in range(n_var):
    d=data[atributos[j]]
    #d=d[abs(zscore(d))<3]
    rango.append([d.min(), d.max()])

for i in range(1):
    dat_filt = data
    for j in range(n_var):
        ax  = sns.boxplot(x=dat_filt[atributos[j]],
                         color=colors[i],
                         flierprops={
                             'marker': 'o',
                             'markersize': 4
                         },
                         ax=axes[j], whis=3,showfliers=True)

        if (i == 0):
            axes[j].set_xlabel(atributos[j])
        else:
            axes[j].set_xlabel("")

        if (j == 0):
            axes[j].set_ylabel("")
        else:
            axes[j].set_ylabel("")

        axes[j].set_yticks([])
        axes[j].grid(axis='x',
                        linestyle='-',
                        linewidth='0.2',
                        color='gray')
        axes[j].grid(axis='y', b=False)

        ax.set_xlim(rango[j][0] - 0.05 * (rango[j][1] - rango[j][0]),
                    rango[j][1] + 0.05 * (rango[j][1] - rango[j][0]))

# %%
# Normalizar los datos
normalizer=preproc.MinMaxScaler()
data_norm=normalizer.fit_transform(data)
data_norm
# Out:
# array([[0.75, 0.  , 0.4 , 0.5 , 1.  ],
#        [0.  , 0.  , 0.  , 0.25, 0.  ],
#        [0.  , 0.25, 0.  , 0.  , 0.  ],
#        ...,
#        [0.  , 0.  , 0.  , 0.25, 0.5 ],
#        [0.  , 0.  , 0.  , 0.25, 0.5 ],
#        [0.25, 0.  , 0.  , 0.5 , 1.  ]])

# %% [markdown]
# ### K-Means

# %%
# Elección de un número adecuado de Clústers atendiendo a las métricas
K=list(range(2,10))
silhouette=[]
calinski=[]
for k in K:
    results = KMeans(n_clusters=k, random_state=0).fit(data_norm)
    sil, cal = measures_silhoutte_calinski(data_norm, results.labels_)
    silhouette.append(sil)
    calinski.append(cal)

# %%
print(silhouette)
print(calinski)
# Out:
# [0.5308268359912561, 0.6269873409049529, 0.6505297888410073, 0.6845637552139876, 0.7355332272617593, 0.7471356340083394, 0.821754631208372, 0.8379008384111823]
# [3140.60638384643, 5238.391164295933, 4669.033612438827, 4674.7895172692815, 4584.643570876157, 4747.170816010209, 5304.438567060736, 5830.317104386284]

# %%
plt.plot(K,calinski, 'bo-')
plt.xlabel('Nº de clústers. K')
plt.ylabel('Calinski')
plt.show()
plt.plot(K,silhouette,'bo-')
plt.ylabel('Silhouette')
plt.xlabel('Nº de clústers. K')
plt.show()

# %% [markdown]
# Nos quedaremos con K=3. Introducir más clústers no gana tanto score y hace la segmentación muy difícil de interpretar.

# %%
K=3
results = KMeans(n_clusters=K, random_state=0).fit(data_norm)
labels=results.labels_
centroids=results.cluster_centers_

# %% [markdown]
# Análisis.

# %%
Counter(labels)
# Out:
# Counter({0: 1974, 1: 2309, 2: 477})

# %%
visualize_centroids(centroids, np.array(data), atributos, denormCentroids=True)

# %%
pairplot(data,atributos,labels)
# Out:
# /home/dcabezas/.local/lib/python3.6/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
dataC=data.copy()
dataC['cluster']=labels
dataC
# Out:
#        TOT_VICTIMAS  TOT_MUERTOS  TOT_HERIDOS_GRAVES  TOT_HERIDOS_LEVES  \
# 17                4            0                   2                  2
# 174               1            0                   0                  1
# 188               1            1                   0                  0
# 191               2            0                   0                  2
# 212               1            0                   1                  0
# ...             ...          ...                 ...                ...
# 89413             1            0                   0                  1
# 89418             1            0                   0                  1
# 89425             1            0                   0                  1
# 89501             1            0                   0                  1
# 89518             2            0                   0                  2
#
#        TOT_VEHICULOS_IMPLICADOS  cluster
# 17                            3        2
# 174                           1        0
# 188                           1        0
# 191                           1        0
# 212                           2        1
# ...                         ...      ...
# 89413                         2        1
# 89418                         1        0
# 89425                         2        1
# 89501                         2        1
# 89518                         3        1
#
# [4760 rows x 6 columns]

# %%
# Box Plot
n_var = len(atributos)
fig, axes = plt.subplots(K, n_var, sharey=True, figsize=(15, 15))
fig.subplots_adjust(wspace=0, hspace=0)

colors = sns.color_palette(palette=None, n_colors=k, desat=None)

rango = []
for j in range(n_var):
    d=dataC[atributos[j]]
    rango.append([d.min(), d.max()])

for i in range(K):
    dat_filt = dataC.loc[dataC['cluster'] == i]
    for j in range(n_var):
        ax  = sns.boxplot(x=dat_filt[atributos[j]],
                         color=colors[i],
                         flierprops={
                             'marker': 'o',
                             'markersize': 4
                         },
                         ax=axes[i, j], whis=3,showfliers=True)

        if (i == K - 1):
            axes[i, j].set_xlabel(atributos[j])
        else:
            axes[i, j].set_xlabel("")

        if (j == 0):
            axes[i, j].set_ylabel("Cluster " + str(i + 1))
        else:
            axes[i, j].set_ylabel("")

        axes[i, j].set_yticks([])
        axes[i, j].grid(axis='x',
                        linestyle='-',
                        linewidth='0.2',
                        color='gray')
        axes[i, j].grid(axis='y', b=False)

        ax.set_xlim(rango[j][0] - 0.05 * (rango[j][1] - rango[j][0]),
                    rango[j][1] + 0.05 * (rango[j][1] - rango[j][0]))

# %% [markdown]
# ### Ward
#
# Ahora utilizaremos un método aglomerativo para formar los clústers

# %%
# Elección de un umbral de distancia por encima del cual no se mezclarán más clústers
K=list(range(2,10))
silhouette=[]
calinski=[]
for k in K:
    results = AgglomerativeClustering(distance_threshold=None, n_clusters=k).fit(data_norm)
    sil, cal = measures_silhoutte_calinski(data_norm, results.labels_)
    silhouette.append(sil)
    calinski.append(cal)

# %%
print(silhouette)
print(calinski)
# Out:
# [0.4809973425150353, 0.5995279945802462, 0.6361140740893952, 0.6776202586025671, 0.7098038750581265, 0.7543779014495403, 0.810664538452725, 0.827487136098117]
# [2646.6469872305943, 4138.1955152857045, 4098.633312218068, 4246.219455512381, 4346.04159818328, 4512.322688574385, 4732.821818410702, 4988.568726899049]

# %%
plt.plot(K,calinski, 'bo-')
plt.xlabel('Nº de clústers. K')
plt.ylabel('Calinski')
plt.show()
plt.plot(K,silhouette,'bo-')
plt.ylabel('Silhouette')
plt.xlabel('Nº de clústers. K')
plt.show()

# %% [markdown]
# También elegimos K=3.

# %%
K=3
results = AgglomerativeClustering(distance_threshold=None, n_clusters=K).fit(data_norm)
labels=results.labels_

# %% [markdown]
# Calculamos los centroides a mano

# %%
dataC=data.copy()
dataC['cluster']=labels
dataC
# Out:
#        TOT_VICTIMAS  TOT_MUERTOS  TOT_HERIDOS_GRAVES  TOT_HERIDOS_LEVES  \
# 17                4            0                   2                  2
# 174               1            0                   0                  1
# 188               1            1                   0                  0
# 191               2            0                   0                  2
# 212               1            0                   1                  0
# ...             ...          ...                 ...                ...
# 89413             1            0                   0                  1
# 89418             1            0                   0                  1
# 89425             1            0                   0                  1
# 89501             1            0                   0                  1
# 89518             2            0                   0                  2
#
#        TOT_VEHICULOS_IMPLICADOS  cluster
# 17                            3        0
# 174                           1        1
# 188                           1        1
# 191                           1        0
# 212                           2        2
# ...                         ...      ...
# 89413                         2        2
# 89418                         1        1
# 89425                         2        2
# 89501                         2        2
# 89518                         3        2
#
# [4760 rows x 6 columns]

# %%
centroids = dataC.groupby('cluster').mean()
centroids
# Out:
#          TOT_VICTIMAS  TOT_MUERTOS  TOT_HERIDOS_GRAVES  TOT_HERIDOS_LEVES  \
# cluster
# 0            3.160767     0.028024            0.172566           2.880531
# 1            1.041261     0.030372            0.220057           0.790831
# 2            1.279846     0.015832            0.141635           1.122379
#
#          TOT_VEHICULOS_IMPLICADOS
# cluster
# 0                        1.572271
# 1                        1.000000
# 2                        2.077022

# %%
centroids=centroids.values
centroids
# Out:
# array([[3.16076696, 0.0280236 , 0.17256637, 2.88053097, 1.57227139],
#        [1.04126074, 0.03037249, 0.22005731, 0.79083095, 1.        ],
#        [1.27984596, 0.01583226, 0.14163457, 1.12237912, 2.07702182]])

# %%
Counter(labels)
# Out:
# Counter({0: 678, 1: 1745, 2: 2337})

# %%
visualize_centroids(centroids, np.array(data), atributos, denormCentroids=False)

# %%
pairplot(data,atributos,labels)
# Out:
# /home/dcabezas/.local/lib/python3.6/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
dataC=data.copy()
dataC['cluster']=labels
dataC
# Out:
#        TOT_VICTIMAS  TOT_MUERTOS  TOT_HERIDOS_GRAVES  TOT_HERIDOS_LEVES  \
# 17                4            0                   2                  2
# 174               1            0                   0                  1
# 188               1            1                   0                  0
# 191               2            0                   0                  2
# 212               1            0                   1                  0
# ...             ...          ...                 ...                ...
# 89413             1            0                   0                  1
# 89418             1            0                   0                  1
# 89425             1            0                   0                  1
# 89501             1            0                   0                  1
# 89518             2            0                   0                  2
#
#        TOT_VEHICULOS_IMPLICADOS  cluster
# 17                            3        0
# 174                           1        1
# 188                           1        1
# 191                           1        0
# 212                           2        2
# ...                         ...      ...
# 89413                         2        2
# 89418                         1        1
# 89425                         2        2
# 89501                         2        2
# 89518                         3        2
#
# [4760 rows x 6 columns]

# %%
# Box Plot
n_var = len(atributos)
fig, axes = plt.subplots(K, n_var, sharey=True, figsize=(15, 15))
fig.subplots_adjust(wspace=0, hspace=0)

colors = sns.color_palette(palette=None, n_colors=k, desat=None)

rango = []
for j in range(n_var):
    d=dataC[atributos[j]]
    rango.append([d.min(), d.max()])

for i in range(K):
    dat_filt = dataC.loc[dataC['cluster'] == i]
    for j in range(n_var):
        ax  = sns.boxplot(x=dat_filt[atributos[j]],
                         color=colors[i],
                         flierprops={
                             'marker': 'o',
                             'markersize': 4
                         },
                         ax=axes[i, j], whis=3,showfliers=True)

        if (i == K - 1):
            axes[i, j].set_xlabel(atributos[j])
        else:
            axes[i, j].set_xlabel("")

        if (j == 0):
            axes[i, j].set_ylabel("Cluster " + str(i + 1))
        else:
            axes[i, j].set_ylabel("")

        axes[i, j].set_yticks([])
        axes[i, j].grid(axis='x',
                        linestyle='-',
                        linewidth='0.2',
                        color='gray')
        axes[i, j].grid(axis='y', b=False)

        ax.set_xlim(rango[j][0] - 0.05 * (rango[j][1] - rango[j][0]),
                    rango[j][1] + 0.05 * (rango[j][1] - rango[j][0]))
